# %%
pip install opendatasets
# Out:
# ...
#   Obtaining dependency information for opendatasets from https://files.pythonhosted.org/packages/00/e7/12300c2f886b846375c78a4f32c0ae1cd20bdcf305b5ac45b8d7eceda3ec/opendatasets-0.1.22-py3-none-any.whl.metadata
#   Using cached opendatasets-0.1.22-py3-none-any.whl.metadata (9.2 kB)
# ...
#   Obtaining dependency information for tqdm from https://files.pythonhosted.org/packages/18/eb/fdb7eb9e48b7b02554e1664afd3bd3f117f6b6d6c5881438a0b055554f9b/tqdm-4.66.4-py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/57.6 kB ? eta -:--:--
#      ------- -------------------------------- 10.2/57.6 kB ? eta -:--:--
#      -------------------- ----------------- 30.7/57.6 kB 262.6 kB/s eta 0:00:01
#      -------------------------------------- 57.6/57.6 kB 434.1 kB/s eta 0:00:00
# ...
#   Using cached kaggle-1.6.17.tar.gz (82 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
# ...

# %%
import opendatasets as od

# %%
datasets_url="https://www.kaggle.com/jsphyg/weather-dataset-rattle-package"

# %%
od.download(datasets_url)
# Out:
# Skipping, found downloaded files in ".\weather-dataset-rattle-package" (use force=True to force download)

# %%
import os

# %%
data_dir="./weather-dataset-rattle-package"

# %%
os.listdir(data_dir)
# Out:
# ['weatherAUS.csv']

# %%
train_csv=data_dir + '/weatherAUS.csv'

# %%
import pandas as pd

# %%
raw_df=pd.read_csv(train_csv)

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %%
raw_df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %%
raw_df.dropna(subset=['RainToday','RainTomorrow'],inplace=True)

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 140787 entries, 0 to 145458
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           140787 non-null  object
#  1   Location       140787 non-null  object
#  2   MinTemp        140319 non-null  float64
#  3   MaxTemp        140480 non-null  float64
#  4   Rainfall       140787 non-null  float64
#  5   Evaporation    81093 non-null   float64
#  6   Sunshine       73982 non-null   float64
#  7   WindGustDir    131624 non-null  object
#  8   WindGustSpeed  131682 non-null  float64
#  9   WindDir9am     131127 non-null  object
#  10  WindDir3pm     137117 non-null  object
#  11  WindSpeed9am   139732 non-null  float64
#  12  WindSpeed3pm   138256 non-null  float64
#  13  Humidity9am    139270 non-null  float64
#  14  Humidity3pm    137286 non-null  float64
#  15  Pressure9am    127044 non-null  float64
#  16  Pressure3pm    127018 non-null  float64
# ...

# %%
import plotly.express as px
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 import plotly.express as px
#       2 import matplotlib
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'plotly'

# %%
px.histogram(raw_df,x='Location',title='Location vs Rainy Days', color='RainToday')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 px.histogram(raw_df,x='Location',title='Location vs Rainy Days', color='RainToday')
#
# NameError: name 'px' is not defined

# %%
px.histogram(raw_df,x='Humidity3pm',title='Humidity3pm vs RainToday',color='RainToday')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 px.histogram(raw_df,x='Humidity3pm',title='Humidity3pm vs RainToday',color='RainToday')
#
# NameError: name 'px' is not defined

# %%
px.histogram(raw_df,x='RainTomorrow',title='RainToday vs RainTomorrow',color='RainToday')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 px.histogram(raw_df,x='RainTomorrow',title='RainToday vs RainTomorrow',color='RainToday')
#
# NameError: name 'px' is not defined

# %%
px.scatter(raw_df.sample(2000),x='MinTemp',y='MaxTemp',title='MinTemp vs MaxTemp',color='RainToday')
# Out:
# <div>                            <div id="85df12b6-d0d5-4036-a7ed-a1757595cb97" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("85df12b6-d0d5-4036-a7ed-a1757595cb97")) {                    Plotly.newPlot(                        "85df12b6-d0d5-4036-a7ed-a1757595cb97",                        [{"hovertemplate":"RainToday=No<br>MinTemp=%{x}<br>MaxTemp=%{y}<extra></extra>","legendgroup":"No","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"No","showlegend":true,"x":[17.8,19.4,11.8,-2.5,19.6,18.7,7.2,12.5,5.0,3.9,10.6,9.4,-2.6,23.8,3.9,12.8,7.9,1.9,18.3,-1.0,22.7,3.2,8.1,22.9,12.0,21.4,6.2,13.8,13.1,4.2,-0.2,-1.0,17.0,16.6,7.5,14.9,14.0,12.1,17.5,12.1,10.7,11.2,12.7,7.5,6.8,17.6,8.0,9.4,3.1,8.5,20.2,11.9,4.6,6.1,17.5,9.3,6.2,12.5,15
# ...

# %%
useSample=False

# %%
sample_fraction=0.1

# %%
if useSample:
    raw_df=raw_df.sample(frac=sample_fraction).copy()

# %%
raw_df
# Out:
#               Date       Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 94870   2013-07-07     Townsville     21.3     27.5       0.0          5.0
# 21615   2010-05-12  NorfolkIsland     18.3     22.1       0.6          3.6
# 100782  2012-06-22   MountGambier      6.1     12.1      28.0          1.2
# 83046   2014-11-08       Dartmoor     18.2     23.3       0.0         13.4
# 117509  2017-02-26     PearceRAAF     14.9     30.6       0.0          NaN
# ...            ...            ...      ...      ...       ...          ...
# 134014  2011-09-10     Launceston      2.1     15.9       0.0          NaN
# 71586   2012-05-08        Mildura      9.2     27.7       0.0          4.2
# 20517   2015-11-02      NorahHead     18.9     26.9       3.0          NaN
# 44157   2013-07-27     Wollongong      8.3     17.7       0.0          NaN
# 73228   2017-01-03        Mildura     12.8     32.7       0.0         10.4
#
# ...
